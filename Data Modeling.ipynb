# %% [markdown]
# Anyone who knows me knows that I enyoy drawing idea learning with documented the processes in jupyter notebook.
# Couse I belive this some core solving any problem and build knowledge.
#
# <div class="alert alert-block alert-success">Having good documentation and well defined process will make you more confident to apply and create something</div>
#
# <code style="background:yellow;color:black">And one of the processes is Data Modeling ! </code>
#
#  ## _So, what does the data modeling process consist of?_
#
#  We can mention :
#  1. Requirements Analysis
#  2. Conceptual Model (ERD)
#  3. Logical Model (Tables and  Relatioships)
#  4. Physical Model (Table creation in database `MySQL` or `PostgreSQL` and so on )

# %% [markdown]
# # Requirement Analysis
#
# Requirement analysis is the initial and fundamental phase in the data modeling process.
# This stage involves undertanding and documenting user and system needs, identifying relevant data, and defining the system's functional and non-functional requirements.
#
# Crucial to ensure that the data model is built to meet stakeholders' expetations and needs.
#
# Step for analyzing requirements:
# 1. Undertanding the problems
# 2. Requirement collection
# 3. Analyisis and documentation
# 4. Requirements validation
#
# Detile theory to build sens of knowledge you can access this [reff.book](http://localhost:8888/edit/Study_burhanudin_6/Books/SQL/Book-5Kimball_The-Data-Warehouse-Toolkit-3rd-Edition-5.pdf)

# %% [markdown]
# # Conceptual (ERD)
#
# It is cretaed through diagrams (ERD) that, These diagrams help visualize entities(Tables), their attributes(fields), and the relationships between them(tables) in an abstract way, without considering implementation details.
#
# To understand the purpose of a conceptual model, let’s understand some important points first:
#
# + Entities
# + Relationships
# + Cardinalities
# + Attributes

# %% [markdown]
# Detile describe about cardinality,ilustrated on cardinality.
#
# Cardinality Notations:
#
# + (0,1): Zero or one occurrence.
# + (1,1): Exactly one occurrence.
# + (0,N): Zero or more occurrences.
# + (1,N): One or more occurrences.
#
# As there is often a lot of confusion in this stage, I will give you some examples:
#
# + 1,1 (One to One): A customer has exactly one address, and an address belongs to only one customer.
# + 1,N (One to Many): A department can have many employees, but an employee can only belong to one department.
# + N,M (Many to Many): A student can enroll in many courses, and a course can have many enrolled students. This is usually modeled using a junction table.
#
# With these concepts, we can create our conceptual model, which is nothing more than a high-level representation of entities and their relationships in a business domain.
#
# Our database is a **habit_tracking** one,
#
# ![Screen Shot 2024-11-04 at 09.06.05.png](attachment:55b277b8-0def-4efd-9250-852752ba299d.png)
#
# and I left the conceptual model without the specified attributes. Only the entities, relationships, and cardinality.
#
# ![Screen Shot 2024-11-04 at 08.59.56.png](attachment:acc975b0-7be3-49b7-8b05-96adc84913d6.png)

# %% [markdown]
# # Logical Model (Tables and Relationships)
# The Logical Model is a more detailed representation of the database, which translates the conceptual model into terms closer to physical implementation. The logical modeling does not include indexes and constraints, only the representation of tables and their relationships.
#
# It describes the tables, their attributes, and the relationships between them in a more concrete way, using data modeling languages like the Relational Model.
#
# In this phase, the entities of the ERD/ERM(Entity Relationship Model) are mapped to tables, attributes are mapped to columns, and relationships are mapped to foreign keys.
#
# The logical model serves as a basis for implementing the database and is used to design queries and transactions.
#
# + table **contacts**
#   ![Screen Shot 2024-11-04 at 09.17.15.png](attachment:eb4e0553-68b9-48b2-86b1-a3373df28441.png)
#
# + table **goals**
#   ![Screen Shot 2024-11-04 at 09.22.03.png](attachment:f6e33457-b440-4e90-a00a-7d595e721dd2.png)
#
# + table **habits**
#   ![Screen Shot 2024-11-04 at 09.26.41.png](attachment:3f57dcd7-8c41-4316-a1f0-5717a09c8f08.png)
#
# + table **tracking**
#   ![Screen Shot 2024-11-04 at 09.29.32.png](attachment:fa6ae492-70ee-42c5-9de9-4143dae5ce08.png)
#
# ## Retationship
#
# + **contacts vs habits**
#   ![Screen Shot 2024-11-04 at 09.36.37.png](attachment:60238b8c-83c9-4141-b307-47bc06159550.png)
# + **habits vs trackings**
#   ![Screen Shot 2024-11-04 at 09.38.52.png](attachment:54a8db7d-99a2-4f6a-a710-bdfb4aac6bad.png)
#
# ## ERD
#
# ![Screen Shot 2024-11-04 at 09.44.47.png](attachment:a4bf5a2d-3bcf-4a99-b99a-657eb158f140.png)

# %% [markdown]
# # Physical Model (Table Creation in the Database)
# The Physical Model is the concrete implementation of the database, which involves the actual creation of tables and other objects in the database as defined in the logical model.
#
# It describes how data will be stored and accessed physically in the database, including details such as data types, indexes, integrity constraints, and partitions.
#
# The physical model is specific to the chosen database management system (DBMS) and is often created using SQL (Structured Query Language) or database modeling tools.

# %% [raw]
# -- This script was generated by the ERD tool in pgAdmin 4.
# -- Please log an issue at https://redmine.postgresql.org/projects/pgadmin4/issues/new if you find any bugs, including reproduction steps.
# BEGIN;
#
#
# CREATE TABLE IF NOT EXISTS public.contacts
# (
#     contacts_id integer NOT NULL,
#     name character varying(50) NOT NULL,
#     surename character varying(50) NOT NULL,
#     email character varying(50) NOT NULL,
#     phone_number character varying(50) NOT NULL,
#     status bit,
#     PRIMARY KEY (contacts_id)
# );
#
# CREATE TABLE IF NOT EXISTS public.goals
# (
#     id integer NOT NULL,
#     name character varying NOT NULL,
#     description character varying NOT NULL,
#     contacts_id integer NOT NULL,
#     start date NOT NULL,
#     "end" date NOT NULL,
#     achieved bit,
#     status bit,
#     PRIMARY KEY (id)
# );
# ALTER TABLE goals ADD CONSTRAINT u_goals_goal_id UNIQUE (id);
#
# CREATE TABLE IF NOT EXISTS public.habits
# (
#     id integer NOT NULL,
#     name character varying(50) NOT NULL,
#     description character varying(150) NOT NULL,
#     contacts_id integer NOT NULL,
#     per_week integer NOT NULL,
#     per_month integer NOT NULL,
#     per_year integer NOT NULL,
#     status bit,
#     PRIMARY KEY (id)
# );
#
# CREATE TABLE IF NOT EXISTS public.tracking
# (
#     id integer NOT NULL,
#     habit_id integer NOT NULL,
#     date date NOT NULL,
#     level bit,
#     PRIMARY KEY (id)
# );
#
# ALTER TABLE IF EXISTS public.contacts
#     ADD FOREIGN KEY (contacts_id)
#     REFERENCES public.goals (contacts_id) MATCH SIMPLE
#     ON UPDATE NO ACTION
#     ON DELETE NO ACTION
#     NOT VALID;
#
#
# ALTER TABLE IF EXISTS public.contacts
#     ADD FOREIGN KEY (contacts_id)
#     REFERENCES public.habits (contacts_id) MATCH SIMPLE
#     ON UPDATE NO ACTION
#     ON DELETE NO ACTION
#     NOT VALID;
#
#
# ALTER TABLE IF EXISTS public.habits
#     ADD FOREIGN KEY (id)
#     REFERENCES public.tracking (habit_id) MATCH SIMPLE
#     ON UPDATE NO ACTION
#     ON DELETE NO ACTION
#     NOT VALID;
#
#
# END;
